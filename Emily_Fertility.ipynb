# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
population_estimates = pd.read_csv("Population-EstimatesData.csv")
population_estimates.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  \
# 0  Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 1                          Age dependency ratio, old     SP.POP.DPND.OL
# 2                        Age dependency ratio, young     SP.POP.DPND.YG
# 3       Age population, age 00, female, interpolated  SP.POP.AG00.FE.IN
# 4         Age population, age 00, male, interpolated  SP.POP.AG00.MA.IN
#
#         1960       1961       1962       1963       1964       1965  ...  \
# 0  88.061110  89.489513  90.782451  91.898948  92.728007  93.201290  ...
# 1   6.591951   6.700903   6.793279   6.867327   6.919224   6.947790  ...
# 2  81.324186  82.626198  83.789155  84.767354  85.474209  85.872972  ...
# 3        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 4        NaN        NaN        NaN        NaN        NaN        NaN  ...
#
#         2041       2042       2043       2044       2045       2046  \
# 0  54.244434  54.356396  54.502067  54.676725  54.874161  55.102246
# 1  12.973244  13.345549  13.732773  14.132766  14.544481  14.946251
# 2  40.757181  40.542064  40.345297  40.162781  39.987572  39.845466
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#         2047       2048       2049       2050
# 0  55.331887  55.562180  55.789065  56.009450
# 1  15.349197  15.755873  16.168726  16.589418
# 2  39.699291  39.546177  39.380479  39.197560
# 3        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN
#
# [5 rows x 95 columns]

# %%
# Set new index to Country Name
df = population_estimates.set_index("Country Name")
df.head()
# Out:
#              Country Code                                     Indicator Name  \
# Country Name
# Arab World            ARB  Age dependency ratio (% of working-age populat...
# Arab World            ARB                          Age dependency ratio, old
# Arab World            ARB                        Age dependency ratio, young
# Arab World            ARB       Age population, age 00, female, interpolated
# Arab World            ARB         Age population, age 00, male, interpolated
#
#                  Indicator Code       1960       1961       1962       1963  \
# Country Name
# Arab World          SP.POP.DPND  88.061110  89.489513  90.782451  91.898948
# Arab World       SP.POP.DPND.OL   6.591951   6.700903   6.793279   6.867327
# Arab World       SP.POP.DPND.YG  81.324186  82.626198  83.789155  84.767354
# Arab World    SP.POP.AG00.FE.IN        NaN        NaN        NaN        NaN
# Arab World    SP.POP.AG00.MA.IN        NaN        NaN        NaN        NaN
#
#                    1964       1965       1966  ...       2041       2042  \
# Country Name                                   ...
# Arab World    92.728007  93.201290  94.087535  ...  54.244434  54.356396
# Arab World     6.919224   6.947790   7.015592  ...  12.973244  13.345549
# Arab World    85.474209  85.872972  86.674248  ...  40.757181  40.542064
# Arab World          NaN        NaN        NaN  ...        NaN        NaN
# Arab World          NaN        NaN        NaN  ...        NaN        NaN
#
#                    2043       2044       2045       2046       2047  \
# Country Name
# Arab World    54.502067  54.676725  54.874161  55.102246  55.331887
# Arab World    13.732773  14.132766  14.544481  14.946251  15.349197
# Arab World    40.345297  40.162781  39.987572  39.845466  39.699291
# Arab World          NaN        NaN        NaN        NaN        NaN
# Arab World          NaN        NaN        NaN        NaN        NaN
#
#                    2048       2049       2050
# Country Name
# Arab World    55.562180  55.789065  56.009450
# Arab World    15.755873  16.168726  16.589418
# Arab World    39.546177  39.380479  39.197560
# Arab World          NaN        NaN        NaN
# Arab World          NaN        NaN        NaN
#
# [5 rows x 94 columns]

# %%
# Grab the eight regions we'll be using
reduced_df = df.loc[["Central Europe and the Baltics", "East Asia & Pacific", "European Union",
                                "Latin America & Caribbean", "Middle East & North Africa", "South Asia", "Sub-Saharan Africa", "United States"]]
reduced_df
# Out:
#                                Country Code  \
# Country Name
# Central Europe and the Baltics          CEB
# Central Europe and the Baltics          CEB
# Central Europe and the Baltics          CEB
# Central Europe and the Baltics          CEB
# Central Europe and the Baltics          CEB
# ...                                     ...
# United States                           USA
# United States                           USA
# United States                           USA
# United States                           USA
# United States                           USA
#
#                                                                    Indicator Name  \
# Country Name
# Central Europe and the Baltics  Age dependency ratio (% of working-age populat...
# Central Europe and the Baltics                          Age dependency ratio, old
# Central Europe and the Baltics                        Age dependency ratio, young
# Central Europe and the Baltics       Age population, age 00, female, interpolated
# Central Europe and the Baltics         Age population, age 00, male, interpolated
# ...                                                                           ...
# United States                                  Rural population growth (annual %)
# United States                   Sex ratio at birth (male births per female bir...
# United States                                                    Urban population
# United States                            Urban population (% of total population)
# United States                                  Urban population growth (annual %)
#
#                                    Indicator Code          1960          1961  \
# Country Name
# Central Europe and the Baltics        SP.POP.DPND  5.741188e+01  5.752730e+01
# Central Europe and the Baltics     SP.POP.DPND.OL  1.134335e+01  1.164324e+01
# Central Europe and the Baltics     SP.POP.DPND.YG  4.587778e+01  4.567246e+01
# Central Europe and the Baltics  SP.POP.AG00.FE.IN           NaN           NaN
# Central Europe and the Baltics  SP.POP.AG00.MA.IN           NaN           NaN
# ...                                           ...           ...           ...
# United States                      SP.RUR.TOTL.ZG -1.953745e-02  3.797679e-01
# United States                      SP.POP.BRTH.MF           NaN           NaN
# United States                         SP.URB.TOTL  1.264625e+08  1.292762e+08
# United States                   SP.URB.TOTL.IN.ZS  6.999600e+01  7.037700e+01
# United States                         SP.URB.GROW  2.449104e+00  2.200571e+00
#
#                                         1962          1963          1964  \
# Country Name
# Central Europe and the Baltics  5.728712e+01  5.677139e+01  5.614491e+01
# Central Europe and the Baltics  1.195043e+01  1.225932e+01  1.256735e+01
# Central Europe and the Baltics  4.512306e+01  4.431009e+01  4.339136e+01
# Central Europe and the Baltics           NaN           NaN           NaN
# Central Europe and the Baltics           NaN           NaN           NaN
# ...                                      ...           ...           ...
# United States                   2.469108e-01  1.415862e-01  8.493718e-02
# United States                   1.050000e+00           NaN           NaN
# United States                   1.319887e+08  1.346154e+08  1.372160e+08
# United States                   7.075700e+01  7.113400e+01  7.150800e+01
# United States                   2.076494e+00  1.970559e+00  1.913437e+00
#
#                                         1965          1966  ...          2041  \
# Country Name                                                ...
# Central Europe and the Baltics  5.551517e+01  5.471579e+01  ...  6.521464e+01
# Central Europe and the Baltics  1.287642e+01  1.319988e+01  ...  4.318770e+01
# Central Europe and the Baltics  4.246881e+01  4.137372e+01  ...  2.198657e+01
# Central Europe and the Baltics           NaN           NaN  ...           NaN
# Central Europe and the Baltics           NaN           NaN  ...           NaN
# ...                                      ...           ...  ...           ...
# United States                  -6.049969e-02 -1.623757e-01  ...           NaN
# United States                            NaN           NaN  ...           NaN
# United States                   1.396631e+08  1.420087e+08  ...  3.262880e+08
# United States                   7.187900e+01  7.224700e+01  ...  8.735200e+01
# United States                   1.767653e+00  1.665559e+00  ...           NaN
#
#                                         2042          2043          2044  \
# Country Name
# Central Europe and the Baltics  6.646455e+01  6.776753e+01  6.906237e+01
# Central Europe and the Baltics  4.425557e+01  4.535228e+01  4.642422e+01
# Central Europe and the Baltics  2.217074e+01  2.237985e+01  2.260623e+01
# Central Europe and the Baltics           NaN           NaN           NaN
# Central Europe and the Baltics           NaN           NaN           NaN
# ...                                      ...           ...           ...
# United States                            NaN           NaN           NaN
# United States                   1.047000e+00           NaN           NaN
# United States                   3.284070e+08  3.305070e+08  3.325870e+08
# United States                   8.756400e+01  8.777400e+01  8.798000e+01
# United States                            NaN           NaN           NaN
#
#                                         2045          2046          2047  \
# Country Name
# Central Europe and the Baltics  7.031534e+01  7.158719e+01  7.275529e+01
# Central Europe and the Baltics  4.744606e+01  4.845903e+01  4.936855e+01
# Central Europe and the Baltics  2.284224e+01  2.310576e+01  2.336620e+01
# Central Europe and the Baltics           NaN           NaN           NaN
# Central Europe and the Baltics           NaN           NaN           NaN
# ...                                      ...           ...           ...
# United States                            NaN           NaN           NaN
# United States                            NaN           NaN  1.047000e+00
# United States                   3.346630e+08  3.367340e+08  3.388110e+08
# United States                   8.818400e+01  8.838400e+01  8.858200e+01
# United States                            NaN           NaN           NaN
#
#                                         2048          2049          2050
# Country Name
# Central Europe and the Baltics  7.386537e+01  7.498979e+01  7.617579e+01
# Central Europe and the Baltics  5.021531e+01  5.107022e+01  5.198438e+01
# Central Europe and the Baltics  2.362480e+01  2.388381e+01  2.414218e+01
# Central Europe and the Baltics           NaN           NaN           NaN
# Central Europe and the Baltics           NaN           NaN           NaN
# ...                                      ...           ...           ...
# United States                            NaN           NaN           NaN
# United States                            NaN           NaN           NaN
# United States                   3.408870e+08  3.429730e+08  3.450350e+08
# United States                   8.877600e+01  8.896800e+01  8.915600e+01
# United States                            NaN           NaN           NaN
#
# [1400 rows x 94 columns]

# %%
#Move the Country Name index back into a column
reduced_df2 = reduced_df.reset_index(level='Country Name')
reduced_df2
# Out:
#                         Country Name Country Code  \
# 0     Central Europe and the Baltics          CEB
# 1     Central Europe and the Baltics          CEB
# 2     Central Europe and the Baltics          CEB
# 3     Central Europe and the Baltics          CEB
# 4     Central Europe and the Baltics          CEB
# ...                              ...          ...
# 1395                   United States          USA
# 1396                   United States          USA
# 1397                   United States          USA
# 1398                   United States          USA
# 1399                   United States          USA
#
#                                          Indicator Name     Indicator Code  \
# 0     Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 1                             Age dependency ratio, old     SP.POP.DPND.OL
# 2                           Age dependency ratio, young     SP.POP.DPND.YG
# 3          Age population, age 00, female, interpolated  SP.POP.AG00.FE.IN
# 4            Age population, age 00, male, interpolated  SP.POP.AG00.MA.IN
# ...                                                 ...                ...
# 1395                 Rural population growth (annual %)     SP.RUR.TOTL.ZG
# 1396  Sex ratio at birth (male births per female bir...     SP.POP.BRTH.MF
# 1397                                   Urban population        SP.URB.TOTL
# 1398           Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1399                 Urban population growth (annual %)        SP.URB.GROW
#
#               1960          1961          1962          1963          1964  \
# 0     5.741188e+01  5.752730e+01  5.728712e+01  5.677139e+01  5.614491e+01
# 1     1.134335e+01  1.164324e+01  1.195043e+01  1.225932e+01  1.256735e+01
# 2     4.587778e+01  4.567246e+01  4.512306e+01  4.431009e+01  4.339136e+01
# 3              NaN           NaN           NaN           NaN           NaN
# 4              NaN           NaN           NaN           NaN           NaN
# ...            ...           ...           ...           ...           ...
# 1395 -1.953745e-02  3.797679e-01  2.469108e-01  1.415862e-01  8.493718e-02
# 1396           NaN           NaN  1.050000e+00           NaN           NaN
# 1397  1.264625e+08  1.292762e+08  1.319887e+08  1.346154e+08  1.372160e+08
# 1398  6.999600e+01  7.037700e+01  7.075700e+01  7.113400e+01  7.150800e+01
# 1399  2.449104e+00  2.200571e+00  2.076494e+00  1.970559e+00  1.913437e+00
#
#               1965  ...          2041          2042          2043  \
# 0     5.551517e+01  ...  6.521464e+01  6.646455e+01  6.776753e+01
# 1     1.287642e+01  ...  4.318770e+01  4.425557e+01  4.535228e+01
# 2     4.246881e+01  ...  2.198657e+01  2.217074e+01  2.237985e+01
# 3              NaN  ...           NaN           NaN           NaN
# 4              NaN  ...           NaN           NaN           NaN
# ...            ...  ...           ...           ...           ...
# 1395 -6.049969e-02  ...           NaN           NaN           NaN
# 1396           NaN  ...           NaN  1.047000e+00           NaN
# 1397  1.396631e+08  ...  3.262880e+08  3.284070e+08  3.305070e+08
# 1398  7.187900e+01  ...  8.735200e+01  8.756400e+01  8.777400e+01
# 1399  1.767653e+00  ...           NaN           NaN           NaN
#
#               2044          2045          2046          2047          2048  \
# 0     6.906237e+01  7.031534e+01  7.158719e+01  7.275529e+01  7.386537e+01
# 1     4.642422e+01  4.744606e+01  4.845903e+01  4.936855e+01  5.021531e+01
# 2     2.260623e+01  2.284224e+01  2.310576e+01  2.336620e+01  2.362480e+01
# 3              NaN           NaN           NaN           NaN           NaN
# 4              NaN           NaN           NaN           NaN           NaN
# ...            ...           ...           ...           ...           ...
# 1395           NaN           NaN           NaN           NaN           NaN
# 1396           NaN           NaN           NaN  1.047000e+00           NaN
# 1397  3.325870e+08  3.346630e+08  3.367340e+08  3.388110e+08  3.408870e+08
# 1398  8.798000e+01  8.818400e+01  8.838400e+01  8.858200e+01  8.877600e+01
# 1399           NaN           NaN           NaN           NaN           NaN
#
#               2049          2050
# 0     7.498979e+01  7.617579e+01
# 1     5.107022e+01  5.198438e+01
# 2     2.388381e+01  2.414218e+01
# 3              NaN           NaN
# 4              NaN           NaN
# ...            ...           ...
# 1395           NaN           NaN
# 1396           NaN           NaN
# 1397  3.429730e+08  3.450350e+08
# 1398  8.896800e+01  8.915600e+01
# 1399           NaN           NaN
#
# [1400 rows x 95 columns]

# %%
# Set new index to Indicator Name
reduced_df3 = reduced_df2.set_index("Indicator Name")
reduced_df3.head()
# Out:
#                                                                       Country Name  \
# Indicator Name
# Age dependency ratio (% of working-age population)  Central Europe and the Baltics
# Age dependency ratio, old                           Central Europe and the Baltics
# Age dependency ratio, young                         Central Europe and the Baltics
# Age population, age 00, female, interpolated        Central Europe and the Baltics
# Age population, age 00, male, interpolated          Central Europe and the Baltics
#
#                                                    Country Code  \
# Indicator Name
# Age dependency ratio (% of working-age population)          CEB
# Age dependency ratio, old                                   CEB
# Age dependency ratio, young                                 CEB
# Age population, age 00, female, interpolated                CEB
# Age population, age 00, male, interpolated                  CEB
#
#                                                        Indicator Code  \
# Indicator Name
# Age dependency ratio (% of working-age population)        SP.POP.DPND
# Age dependency ratio, old                              SP.POP.DPND.OL
# Age dependency ratio, young                            SP.POP.DPND.YG
# Age population, age 00, female, interpolated        SP.POP.AG00.FE.IN
# Age population, age 00, male, interpolated          SP.POP.AG00.MA.IN
#
#                                                          1960       1961  \
# Indicator Name
# Age dependency ratio (% of working-age population)  57.411876  57.527304
# Age dependency ratio, old                           11.343346  11.643242
# Age dependency ratio, young                         45.877783  45.672459
# Age population, age 00, female, interpolated              NaN        NaN
# Age population, age 00, male, interpolated                NaN        NaN
#
#                                                          1962       1963  \
# Indicator Name
# Age dependency ratio (% of working-age population)  57.287119  56.771392
# Age dependency ratio, old                           11.950425  12.259320
# Age dependency ratio, young                         45.123065  44.310088
# Age population, age 00, female, interpolated              NaN        NaN
# Age population, age 00, male, interpolated                NaN        NaN
#
#                                                          1964       1965  \
# Indicator Name
# Age dependency ratio (% of working-age population)  56.144914  55.515174
# Age dependency ratio, old                           12.567347  12.876417
# Age dependency ratio, young                         43.391358  42.468807
# Age population, age 00, female, interpolated              NaN        NaN
# Age population, age 00, male, interpolated                NaN        NaN
#
#                                                          1966  ...       2041  \
# Indicator Name                                                 ...
# Age dependency ratio (% of working-age population)  54.715793  ...  65.214644
# Age dependency ratio, old                           13.199878  ...  43.187701
# Age dependency ratio, young                         41.373717  ...  21.986570
# Age population, age 00, female, interpolated              NaN  ...        NaN
# Age population, age 00, male, interpolated                NaN  ...        NaN
#
#                                                          2042       2043  \
# Indicator Name
# Age dependency ratio (% of working-age population)  66.464551  67.767528
# Age dependency ratio, old                           44.255566  45.352282
# Age dependency ratio, young                         22.170741  22.379851
# Age population, age 00, female, interpolated              NaN        NaN
# Age population, age 00, male, interpolated                NaN        NaN
#
#                                                          2044       2045  \
# Indicator Name
# Age dependency ratio (% of working-age population)  69.062370  70.315340
# Age dependency ratio, old                           46.424219  47.446057
# Age dependency ratio, young                         22.606232  22.842236
# Age population, age 00, female, interpolated              NaN        NaN
# Age population, age 00, male, interpolated                NaN        NaN
#
#                                                          2046       2047  \
# Indicator Name
# Age dependency ratio (% of working-age population)  71.587189  72.755291
# Age dependency ratio, old                           48.459026  49.368546
# Age dependency ratio, young                         23.105764  23.366196
# Age population, age 00, female, interpolated              NaN        NaN
# Age population, age 00, male, interpolated                NaN        NaN
#
#                                                          2048       2049  \
# Indicator Name
# Age dependency ratio (% of working-age population)  73.865371  74.989787
# Age dependency ratio, old                           50.215312  51.070216
# Age dependency ratio, young                         23.624801  23.883808
# Age population, age 00, female, interpolated              NaN        NaN
# Age population, age 00, male, interpolated                NaN        NaN
#
#                                                          2050
# Indicator Name
# Age dependency ratio (% of working-age population)  76.175794
# Age dependency ratio, old                           51.984375
# Age dependency ratio, young                         24.142179
# Age population, age 00, female, interpolated              NaN
# Age population, age 00, male, interpolated                NaN
#
# [5 rows x 94 columns]

# %%
# Grab the fertility rate births per woman rows
reduced_df4 = reduced_df3.loc[["Fertility rate, total (births per woman)"]]
reduced_df4.head()
# Out:
#                                                             Country Name  \
# Indicator Name
# Fertility rate, total (births per woman)  Central Europe and the Baltics
# Fertility rate, total (births per woman)             East Asia & Pacific
# Fertility rate, total (births per woman)                  European Union
# Fertility rate, total (births per woman)       Latin America & Caribbean
# Fertility rate, total (births per woman)      Middle East & North Africa
#
#                                          Country Code  Indicator Code  \
# Indicator Name
# Fertility rate, total (births per woman)          CEB  SP.DYN.TFRT.IN
# Fertility rate, total (births per woman)          EAS  SP.DYN.TFRT.IN
# Fertility rate, total (births per woman)          EUU  SP.DYN.TFRT.IN
# Fertility rate, total (births per woman)          LCN  SP.DYN.TFRT.IN
# Fertility rate, total (births per woman)          MEA  SP.DYN.TFRT.IN
#
#                                               1960      1961      1962  \
# Indicator Name
# Fertility rate, total (births per woman)  2.497094  2.400683  2.309179
# Fertility rate, total (births per woman)  5.396406  5.471164  5.545254
# Fertility rate, total (births per woman)  2.583469  2.594764  2.590291
# Fertility rate, total (births per woman)  5.882839  5.871677  5.848203
# Fertility rate, total (births per woman)  6.906806  6.921688  6.933832
#
#                                               1963      1964      1965  \
# Indicator Name
# Fertility rate, total (births per woman)  2.313874  2.258712  2.198710
# Fertility rate, total (births per woman)  5.619571  5.677623  5.716044
# Fertility rate, total (births per woman)  2.623556  2.654006  2.596572
# Fertility rate, total (births per woman)  5.810980  5.759644  5.693373
# Fertility rate, total (births per woman)  6.940577  6.940658  6.931592
#
#                                               1966  ...  2041  2042  2043  \
# Indicator Name                                      ...
# Fertility rate, total (births per woman)  2.118629  ...   NaN   NaN   NaN
# Fertility rate, total (births per woman)  5.645718  ...   NaN   NaN   NaN
# Fertility rate, total (births per woman)  2.556209  ...   NaN   NaN   NaN
# Fertility rate, total (births per woman)  5.613752  ...   NaN   NaN   NaN
# Fertility rate, total (births per woman)  6.911719  ...   NaN   NaN   NaN
#
#                                           2044  2045  2046  2047  2048  2049  \
# Indicator Name
# Fertility rate, total (births per woman)   NaN  1.67   NaN   NaN   NaN   NaN
# Fertility rate, total (births per woman)   NaN  1.79   NaN   NaN   NaN   NaN
# Fertility rate, total (births per woman)   NaN  1.69   NaN   NaN   NaN   NaN
# Fertility rate, total (births per woman)   NaN  1.75   NaN   NaN   NaN   NaN
# Fertility rate, total (births per woman)   NaN  2.22   NaN   NaN   NaN   NaN
#
#                                           2050
# Indicator Name
# Fertility rate, total (births per woman)  1.69
# Fertility rate, total (births per woman)  1.79
# Fertility rate, total (births per woman)  1.70
# Fertility rate, total (births per woman)  1.74
# Fertility rate, total (births per woman)  2.16
#
# [5 rows x 94 columns]

# %%
#Move the Indicator Name index back into a column
reduced_df5 = reduced_df4.reset_index(level='Indicator Name')
reduced_df5.head()
# Out:
#                              Indicator Name                    Country Name  \
# 0  Fertility rate, total (births per woman)  Central Europe and the Baltics
# 1  Fertility rate, total (births per woman)             East Asia & Pacific
# 2  Fertility rate, total (births per woman)                  European Union
# 3  Fertility rate, total (births per woman)       Latin America & Caribbean
# 4  Fertility rate, total (births per woman)      Middle East & North Africa
#
#   Country Code  Indicator Code      1960      1961      1962      1963  \
# 0          CEB  SP.DYN.TFRT.IN  2.497094  2.400683  2.309179  2.313874
# 1          EAS  SP.DYN.TFRT.IN  5.396406  5.471164  5.545254  5.619571
# 2          EUU  SP.DYN.TFRT.IN  2.583469  2.594764  2.590291  2.623556
# 3          LCN  SP.DYN.TFRT.IN  5.882839  5.871677  5.848203  5.810980
# 4          MEA  SP.DYN.TFRT.IN  6.906806  6.921688  6.933832  6.940577
#
#        1964      1965  ...  2041  2042  2043  2044  2045  2046  2047  2048  \
# 0  2.258712  2.198710  ...   NaN   NaN   NaN   NaN  1.67   NaN   NaN   NaN
# 1  5.677623  5.716044  ...   NaN   NaN   NaN   NaN  1.79   NaN   NaN   NaN
# 2  2.654006  2.596572  ...   NaN   NaN   NaN   NaN  1.69   NaN   NaN   NaN
# 3  5.759644  5.693373  ...   NaN   NaN   NaN   NaN  1.75   NaN   NaN   NaN
# 4  6.940658  6.931592  ...   NaN   NaN   NaN   NaN  2.22   NaN   NaN   NaN
#
#    2049  2050
# 0   NaN  1.69
# 1   NaN  1.79
# 2   NaN  1.70
# 3   NaN  1.74
# 4   NaN  2.16
#
# [5 rows x 95 columns]

# %%
# Reorganizing the columns where Country Name comes before Indicator Name
organized_df = reduced_df5[["Country Name","1970","1975","1980","1985","1990","1995","2000","2005","2010","2015","2020","2025","2030","2035","2040","2045","2050"]]
organized_df.head()
# Out:
#                      Country Name  1970  1975  1980  1985  1990  1995  2000  \
# 0  Central Europe and the Baltics  2.29  2.34  2.19  2.16  1.93  1.47  1.32
# 1             East Asia & Pacific  5.26  3.93  2.98  2.83  2.47  1.96  1.85
# 2                  European Union  2.36  2.06  1.87  1.73  1.66  1.45  1.46
# 3       Latin America & Caribbean  5.21  4.69  4.19  3.69  3.26  2.92  2.63
# 4      Middle East & North Africa  6.73  6.44  6.23  5.79  4.88  3.87  3.19
#
#    2005  2010  2015  2020  2025  2030  2035  2040  2045  2050
# 0  1.31  1.47  1.45  1.54  1.57  1.60  1.63  1.65  1.67  1.69
# 1  1.81  1.82  1.83  1.83  1.82  1.81  1.81  1.80  1.79  1.79
# 2  1.50  1.61  1.57  1.58  1.61  1.63  1.65  1.67  1.69  1.70
# 3  2.36  2.19  2.09  1.99  1.91  1.85  1.81  1.77  1.75  1.74
# 4  2.90  2.90  2.89  2.74  2.60  2.48  2.38  2.30  2.22  2.16

# %%
# Set new index to Country Name
organized_df2 = organized_df.set_index("Country Name")
organized_df2
# Out:
#                                 1970  1975  1980  1985  1990  1995  2000  \
# Country Name
# Central Europe and the Baltics  2.29  2.34  2.19  2.16  1.93  1.47  1.32
# East Asia & Pacific             5.26  3.93  2.98  2.83  2.47  1.96  1.85
# European Union                  2.36  2.06  1.87  1.73  1.66  1.45  1.46
# Latin America & Caribbean       5.21  4.69  4.19  3.69  3.26  2.92  2.63
# Middle East & North Africa      6.73  6.44  6.23  5.79  4.88  3.87  3.19
# South Asia                      5.79  5.46  5.12  4.76  4.30  3.89  3.51
# Sub-Saharan Africa              6.74  6.80  6.77  6.64  6.35  6.02  5.76
# United States                   2.48  1.77  1.84  1.84  2.08  1.98  2.06
#
#                                 2005  2010  2015  2020  2025  2030  2035  \
# Country Name
# Central Europe and the Baltics  1.31  1.47  1.45  1.54  1.57  1.60  1.63
# East Asia & Pacific             1.81  1.82  1.83  1.83  1.82  1.81  1.81
# European Union                  1.50  1.61  1.57  1.58  1.61  1.63  1.65
# Latin America & Caribbean       2.36  2.19  2.09  1.99  1.91  1.85  1.81
# Middle East & North Africa      2.90  2.90  2.89  2.74  2.60  2.48  2.38
# South Asia                      3.14  2.75  2.47  2.34  2.22  2.12  2.04
# Sub-Saharan Africa              5.52  5.26  4.91  4.56  4.24  3.95  3.69
# United States                   2.06  1.93  1.84  1.77  1.79  1.80  1.80
#
#                                 2040  2045  2050
# Country Name
# Central Europe and the Baltics  1.65  1.67  1.69
# East Asia & Pacific             1.80  1.79  1.79
# European Union                  1.67  1.69  1.70
# Latin America & Caribbean       1.77  1.75  1.74
# Middle East & North Africa      2.30  2.22  2.16
# South Asia                      1.97  1.92  1.88
# Sub-Saharan Africa              3.46  3.26  3.08
# United States                   1.80  1.80  1.81

# %%
# Create a series for 1970-2050
series1 = organized_df2.loc["Central Europe and the Baltics"]
series2 = organized_df2.loc["East Asia & Pacific"]
series3 = organized_df2.loc["European Union"]
series4 = organized_df2.loc["Latin America & Caribbean"]
series5 = organized_df2.loc["Middle East & North Africa"]
series6 = organized_df2.loc["South Asia"]
series7 = organized_df2.loc["Sub-Saharan Africa"]
series8 = organized_df2.loc["United States"]

# %%
# Create a list of the years that we will use as our x axis
years = [1970,1975,1980,1985,1990,1995,2000,2005,2010,2015,2020,2025,2030,2035,2040,2045,2050]
plt.figure(figsize=(10,6))
# Plot line
plt.plot(years, series1, color="blue", label="Central Europe and the Baltics")
plt.plot(years, series2, color="green", label="East Asia & Pacific")
plt.plot(years, series3, color="red", label="European Union")
plt.plot(years, series4, color="cyan", label="Latin America & Caribbean")
plt.plot(years, series5, color="magenta", label="Middle East & North Africa")
plt.plot(years, series6, color="yellow", label="South Asia")
plt.plot(years, series7, color="orange", label="Sub-Saharan Africa")
plt.plot(years, series8, color="purple", label="United States")

# Place a legend on the chart
plt.legend(loc="best")
plt.title('Global Fertility Rate Over Time', fontdict={'fontweight':'bold', 'fontsize': 18})
#plt.title("Global Fertility Rate Over Time")
plt.ylabel("Fertility Rate", fontsize=14)
legend = plt.legend(loc="best")
legend.get_frame().set_facecolor('none')
plt.gca().legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.grid(True)
#Save the plotted figures as .pngs
plt.savefig("fertility_over_time.png")

# Print our chart to the screen
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
