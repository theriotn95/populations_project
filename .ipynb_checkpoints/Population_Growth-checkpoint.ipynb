# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
population_estimates = pd.read_csv("Population-EstimatesData.csv")
population_estimates.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  \
# 0  Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 1                          Age dependency ratio, old     SP.POP.DPND.OL
# 2                        Age dependency ratio, young     SP.POP.DPND.YG
# 3       Age population, age 00, female, interpolated  SP.POP.AG00.FE.IN
# 4         Age population, age 00, male, interpolated  SP.POP.AG00.MA.IN
#
#         1960       1961       1962       1963       1964       1965  ...  \
# 0  88.061110  89.489513  90.782451  91.898948  92.728007  93.201290  ...
# 1   6.591951   6.700903   6.793279   6.867327   6.919224   6.947790  ...
# 2  81.324186  82.626198  83.789155  84.767354  85.474209  85.872972  ...
# ...

# %%
# Set new index to Indicator Name
df = population_estimates.set_index("Indicator Name")
df.head()
# Out:
#                                                    Country Name Country Code  \
# Indicator Name
# Age dependency ratio (% of working-age population)   Arab World          ARB
# Age dependency ratio, old                            Arab World          ARB
# Age dependency ratio, young                          Arab World          ARB
# Age population, age 00, female, interpolated         Arab World          ARB
# Age population, age 00, male, interpolated           Arab World          ARB
#
#                                                        Indicator Code  \
# Indicator Name
# Age dependency ratio (% of working-age population)        SP.POP.DPND
# Age dependency ratio, old                              SP.POP.DPND.OL
# Age dependency ratio, young                            SP.POP.DPND.YG
# Age population, age 00, female, interpolated        SP.POP.AG00.FE.IN
# Age population, age 00, male, interpolated          SP.POP.AG00.MA.IN
#
# ...

# %%
reduced_df = df.loc[["Population, total"]]
reduced_df
# Out:
#                                      Country Name Country Code Indicator Code  \
# Indicator Name
# Population, total                      Arab World          ARB    SP.POP.TOTL
# Population, total          Caribbean small states          CSS    SP.POP.TOTL
# Population, total  Central Europe and the Baltics          CEB    SP.POP.TOTL
# Population, total      Early-demographic dividend          EAR    SP.POP.TOTL
# Population, total             East Asia & Pacific          EAS    SP.POP.TOTL
# ...                                           ...          ...            ...
# Population, total           Virgin Islands (U.S.)          VIR    SP.POP.TOTL
# Population, total              West Bank and Gaza          PSE    SP.POP.TOTL
# Population, total                     Yemen, Rep.          YEM    SP.POP.TOTL
# Population, total                          Zambia          ZMB    SP.POP.TOTL
# Population, total                        Zimbabwe          ZWE    SP.POP.TOTL
#
# ...

# %%
#Move Population, Total back into a column
reduced_df2 = reduced_df.reset_index(level='Indicator Name')
reduced_df2
# Out:
#         Indicator Name                    Country Name Country Code  \
# 0    Population, total                      Arab World          ARB
# 1    Population, total          Caribbean small states          CSS
# 2    Population, total  Central Europe and the Baltics          CEB
# 3    Population, total      Early-demographic dividend          EAR
# 4    Population, total             East Asia & Pacific          EAS
# ..                 ...                             ...          ...
# 254  Population, total           Virgin Islands (U.S.)          VIR
# 255  Population, total              West Bank and Gaza          PSE
# 256  Population, total                     Yemen, Rep.          YEM
# 257  Population, total                          Zambia          ZMB
# 258  Population, total                        Zimbabwe          ZWE
#
#     Indicator Code          1960          1961          1962          1963  \
# ...

# %%
# Set new index to Country Name
reduced_df3 = reduced_df2.set_index("Country Name")
reduced_df3.head()
# Out:
#                                    Indicator Name Country Code Indicator Code  \
# Country Name
# Arab World                      Population, total          ARB    SP.POP.TOTL
# Caribbean small states          Population, total          CSS    SP.POP.TOTL
# Central Europe and the Baltics  Population, total          CEB    SP.POP.TOTL
# Early-demographic dividend      Population, total          EAR    SP.POP.TOTL
# East Asia & Pacific             Population, total          EAS    SP.POP.TOTL
#
#                                         1960          1961          1962  \
# Country Name
# Arab World                      9.219775e+07  9.472451e+07  9.733444e+07
# Caribbean small states          4.194710e+06  4.274060e+06  4.353628e+06
# Central Europe and the Baltics  9.140176e+07  9.223274e+07  9.300950e+07
# Early-demographic dividend      9.800853e+08  1.003279e+09  1.027290e+09
# East Asia & Pacific             1.040958e+09  1.044545e+09  1.059019e+09
#
# ...

# %%
# Grab the eight regions we'll be using
reduced_df4 = reduced_df3.loc[["Central Europe and the Baltics", "East Asia & Pacific", "European Union",
                                "Latin America & Caribbean", "Middle East & North Africa", "South Asia", "Sub-Saharan Africa", "United States"]]
reduced_df4
# Out:
#                                    Indicator Name Country Code Indicator Code  \
# Country Name
# Central Europe and the Baltics  Population, total          CEB    SP.POP.TOTL
# East Asia & Pacific             Population, total          EAS    SP.POP.TOTL
# European Union                  Population, total          EUU    SP.POP.TOTL
# Latin America & Caribbean       Population, total          LCN    SP.POP.TOTL
# Middle East & North Africa      Population, total          MEA    SP.POP.TOTL
# South Asia                      Population, total          SAS    SP.POP.TOTL
# Sub-Saharan Africa              Population, total          SSF    SP.POP.TOTL
# United States                   Population, total          USA    SP.POP.TOTL
#
#                                         1960          1961          1962  \
# Country Name
# Central Europe and the Baltics  9.140176e+07  9.223274e+07  9.300950e+07
# East Asia & Pacific             1.040958e+09  1.044545e+09  1.059019e+09
# ...

# %%
# Create a new dataframe with all the columns we'll be using
reduced_df4 = reduced_df4[["1970","1975","1980","1985","1990","1995","2000","2005","2010","2015","2020","2025","2030","2035","2040","2045","2050"]]
reduced_df4
# Out:
#                                         1970          1975          1980  \
# Country Name
# Central Europe and the Baltics  9.913455e+07  1.028606e+08  1.065767e+08
# East Asia & Pacific             1.290384e+09  1.443359e+09  1.559195e+09
# European Union                  4.419862e+08  4.545424e+08  4.642254e+08
# Latin America & Caribbean       2.860272e+08  3.221768e+08  3.605919e+08
# Middle East & North Africa      1.384731e+08  1.589173e+08  1.846286e+08
# South Asia                      7.137113e+08  8.003356e+08  9.006206e+08
# Sub-Saharan Africa              2.905262e+08  3.325835e+08  3.831882e+08
# United States                   2.050520e+08  2.159730e+08  2.272250e+08
#
#                                         1985          1990          1995  \
# Country Name
# Central Europe and the Baltics  1.093607e+08  1.107431e+08  1.098642e+08
# East Asia & Pacific             1.684295e+09  1.822193e+09  1.942431e+09
# ...

# %%
#check the datatypes
reduced_df4.dtypes
# Out:
# 1970    float64
# 1975    float64
# 1980    float64
# 1985    float64
# 1990    float64
# 1995    float64
# 2000    float64
# 2005    float64
# 2010    float64
# 2015    float64
# 2020    float64
# 2025    float64
# 2030    float64
# 2035    float64
# 2040    float64
# 2045    float64
# 2050    float64
# dtype: object

# %%
#Create New df
reduced_df5=reduced_df4.copy()

# %%
#convert the date columns to integers
cols = ["1970","1975","1980","1985","1990","1995","2000","2005","2010","2015","2020","2025","2030","2035","2040","2045","2050"]
reduced_df5[cols] = reduced_df5[cols].applymap(np.int64)
reduced_df5
# Out:
#                                       1970        1975        1980  \
# Country Name
# Central Europe and the Baltics    99134548   102860571   106576687
# East Asia & Pacific             1290384064  1443359147  1559194619
# European Union                   441986158   454542377   464225439
# Latin America & Caribbean        286027166   322176757   360591861
# Middle East & North Africa       138473064   158917328   184628605
# South Asia                       713711349   800335563   900620572
# Sub-Saharan Africa               290526189   332583486   383188232
# United States                    205052000   215973000   227225000
#
#                                       1985        1990        1995  \
# Country Name
# Central Europe and the Baltics   109360713   110743128   109864246
# East Asia & Pacific             1684294889  1822193192  1942431457
# European Union                   470497179   477725565   484222373
# ...

# %%
reduced_df5.dtypes
# Out:
# 1970    int64
# 1975    int64
# 1980    int64
# 1985    int64
# 1990    int64
# 1995    int64
# 2000    int64
# 2005    int64
# 2010    int64
# 2015    int64
# 2020    int64
# 2025    int64
# 2030    int64
# 2035    int64
# 2040    int64
# 2045    int64
# 2050    int64
# dtype: object

# %%
# Create a series for 1970-2050
series1 = reduced_df5.loc["Central Europe and the Baltics"]
series2 = reduced_df5.loc["East Asia & Pacific"]
series3 = reduced_df5.loc["European Union"]
series4 = reduced_df5.loc["Latin America & Caribbean"]
series5 = reduced_df5.loc["Middle East & North Africa"]
series6 = reduced_df5.loc["South Asia"]
series7 = reduced_df5.loc["Sub-Saharan Africa"]
series8 = reduced_df5.loc["United States"]

# %%
# Create a list of the years that we will use as our x axis
years = [1970,1975,1980,1985,1990,1995,2000,2005,2010,2015,2020,2025,2030,2035,2040,2045,2050]
plt.figure(figsize=(10,6))
# Plot line
plt.plot(years, series1, color="blue", label="Central Europe and the Baltics")
plt.plot(years, series2, color="green", label="East Asia & Pacific")
plt.plot(years, series3, color="red", label="European Union")
plt.plot(years, series4, color="cyan", label="Latin America & Caribbean")
plt.plot(years, series5, color="magenta", label="Middle East & North Africa")
plt.plot(years, series6, color="yellow", label="South Asia")
plt.plot(years, series7, color="orange", label="Sub-Saharan Africa")
plt.plot(years, series8, color="purple", label="United States")

# Place a legend on the chart and set our other labels
plt.legend(loc="best")
plt.title('Regional Populations Through Time', fontdict={'fontweight':'bold', 'fontsize': 18})
plt.ylabel("Population, billions", fontsize=14)
legend = plt.legend(loc="best")
legend.get_frame().set_facecolor('none')
plt.gca().legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.grid(True)
#Save the plotted figures as .pngs
plt.savefig("populations_over_time.png")

# Print our chart to the screen
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Question:
# ### What does the population distribution between different regions of the world look like from 1970 through projected 2050?
#
# * East Asia and the Pacific, South Asia, and Sub Saharan Africa lead the charge in future global population growth.
# * However East Asia and the Pacific does level off with just under 2.5billion people by 2030.
# * The European Union and Central Europe and the Baltics see little to no population growth in the last fifty years, nor are they projected to in the next thirty.
# * The U.S. also only increases its population nominally 1970-2050 never reaching 400,000,000, and Latin America and the Caribbean levels off by 2040 with about 760,000,000.
