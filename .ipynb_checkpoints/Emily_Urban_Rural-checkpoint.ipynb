# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
population_estimates = pd.read_csv("Population-EstimatesData.csv")
population_estimates.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  \
# 0  Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 1                          Age dependency ratio, old     SP.POP.DPND.OL
# 2                        Age dependency ratio, young     SP.POP.DPND.YG
# 3       Age population, age 00, female, interpolated  SP.POP.AG00.FE.IN
# 4         Age population, age 00, male, interpolated  SP.POP.AG00.MA.IN
#
#         1960       1961       1962       1963       1964       1965  ...  \
# 0  88.061110  89.489513  90.782451  91.898948  92.728007  93.201290  ...
# 1   6.591951   6.700903   6.793279   6.867327   6.919224   6.947790  ...
# 2  81.324186  82.626198  83.789155  84.767354  85.474209  85.872972  ...
# 3        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 4        NaN        NaN        NaN        NaN        NaN        NaN  ...
#
#         2041       2042       2043       2044       2045       2046  \
# 0  54.244434  54.356396  54.502067  54.676725  54.874161  55.102246
# 1  12.973244  13.345549  13.732773  14.132766  14.544481  14.946251
# 2  40.757181  40.542064  40.345297  40.162781  39.987572  39.845466
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#         2047       2048       2049       2050
# 0  55.331887  55.562180  55.789065  56.009450
# 1  15.349197  15.755873  16.168726  16.589418
# 2  39.699291  39.546177  39.380479  39.197560
# 3        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN
#
# [5 rows x 95 columns]

# %%
# Remove unecessary columns from the DataFrame and save the new DataFrame
# Only keep: "Country Name", "Indicator Name", "1970", "2020",
reduced_df = population_estimates[["Country Name", "Indicator Name", "1970", "2020"]]
reduced_df.head()
# Out:
#   Country Name                                     Indicator Name       1970  \
# 0   Arab World  Age dependency ratio (% of working-age populat...  94.226666
# 1   Arab World                          Age dependency ratio, old   7.073558
# 2   Arab World                        Age dependency ratio, young  86.848912
# 3   Arab World       Age population, age 00, female, interpolated        NaN
# 4   Arab World         Age population, age 00, male, interpolated        NaN
#
#         2020
# 0  61.020120
# 1   7.593050
# 2  51.954725
# 3        NaN
# 4        NaN

# %%
# Set new index to Country Name
df = reduced_df.set_index("Country Name")
df.head()
# Out:
#                                                  Indicator Name       1970  \
# Country Name
# Arab World    Age dependency ratio (% of working-age populat...  94.226666
# Arab World                            Age dependency ratio, old   7.073558
# Arab World                          Age dependency ratio, young  86.848912
# Arab World         Age population, age 00, female, interpolated        NaN
# Arab World           Age population, age 00, male, interpolated        NaN
#
#                    2020
# Country Name
# Arab World    61.020120
# Arab World     7.593050
# Arab World    51.954725
# Arab World          NaN
# Arab World          NaN

# %%
# Grab the eight regions we'll be using
reduced_df2 = df.loc[["Central Europe and the Baltics", "East Asia & Pacific", "European Union",
                                "Latin America & Caribbean", "Middle East & North Africa", "South Asia", "Sub-Saharan Africa", "United States"]]
reduced_df2
# Out:
#                                                                    Indicator Name  \
# Country Name
# Central Europe and the Baltics  Age dependency ratio (% of working-age populat...
# Central Europe and the Baltics                          Age dependency ratio, old
# Central Europe and the Baltics                        Age dependency ratio, young
# Central Europe and the Baltics       Age population, age 00, female, interpolated
# Central Europe and the Baltics         Age population, age 00, male, interpolated
# ...                                                                           ...
# United States                                  Rural population growth (annual %)
# United States                   Sex ratio at birth (male births per female bir...
# United States                                                    Urban population
# United States                            Urban population (% of total population)
# United States                                  Urban population growth (annual %)
#
#                                         1970          2020
# Country Name
# Central Europe and the Baltics  5.237557e+01  5.316262e+01
# Central Europe and the Baltics  1.438745e+01  2.976632e+01
# Central Europe and the Baltics  3.792280e+01  2.335613e+01
# Central Europe and the Baltics           NaN           NaN
# Central Europe and the Baltics           NaN           NaN
# ...                                      ...           ...
# United States                   1.511424e-01           NaN
# United States                            NaN           NaN
# United States                   1.509224e+08  2.743740e+08
# United States                   7.360200e+01  8.266400e+01
# United States                   1.531152e+00           NaN
#
# [1400 rows x 3 columns]

# %%
#Move the Country Name index back into a column
reduced_df3 = reduced_df2.reset_index(level='Country Name')
reduced_df3
# Out:
#                         Country Name  \
# 0     Central Europe and the Baltics
# 1     Central Europe and the Baltics
# 2     Central Europe and the Baltics
# 3     Central Europe and the Baltics
# 4     Central Europe and the Baltics
# ...                              ...
# 1395                   United States
# 1396                   United States
# 1397                   United States
# 1398                   United States
# 1399                   United States
#
#                                          Indicator Name          1970  \
# 0     Age dependency ratio (% of working-age populat...  5.237557e+01
# 1                             Age dependency ratio, old  1.438745e+01
# 2                           Age dependency ratio, young  3.792280e+01
# 3          Age population, age 00, female, interpolated           NaN
# 4            Age population, age 00, male, interpolated           NaN
# ...                                                 ...           ...
# 1395                 Rural population growth (annual %)  1.511424e-01
# 1396  Sex ratio at birth (male births per female bir...           NaN
# 1397                                   Urban population  1.509224e+08
# 1398           Urban population (% of total population)  7.360200e+01
# 1399                 Urban population growth (annual %)  1.531152e+00
#
#               2020
# 0     5.316262e+01
# 1     2.976632e+01
# 2     2.335613e+01
# 3              NaN
# 4              NaN
# ...            ...
# 1395           NaN
# 1396           NaN
# 1397  2.743740e+08
# 1398  8.266400e+01
# 1399           NaN
#
# [1400 rows x 4 columns]

# %%
#Makes sure Country Name is now a column
reduced_df3.columns
# Out:
# Index(['Country Name', 'Indicator Name', '1970', '2020'], dtype='object')

# %%
# Set new index to Indicator Name
reduced_df4 = reduced_df3.set_index("Indicator Name")
reduced_df4.head()
# Out:
#                                                                       Country Name  \
# Indicator Name
# Age dependency ratio (% of working-age population)  Central Europe and the Baltics
# Age dependency ratio, old                           Central Europe and the Baltics
# Age dependency ratio, young                         Central Europe and the Baltics
# Age population, age 00, female, interpolated        Central Europe and the Baltics
# Age population, age 00, male, interpolated          Central Europe and the Baltics
#
#                                                          1970       2020
# Indicator Name
# Age dependency ratio (% of working-age population)  52.375566  53.162625
# Age dependency ratio, old                           14.387453  29.766316
# Age dependency ratio, young                         37.922797  23.356127
# Age population, age 00, female, interpolated              NaN        NaN
# Age population, age 00, male, interpolated                NaN        NaN

# %%
# Grab the Urban population (% of total population) indicator name
reduced_df5 = reduced_df4.loc[["Urban population (% of total population)"]]
reduced_df5
# Out:
#                                                             Country Name  \
# Indicator Name
# Urban population (% of total population)  Central Europe and the Baltics
# Urban population (% of total population)             East Asia & Pacific
# Urban population (% of total population)                  European Union
# Urban population (% of total population)       Latin America & Caribbean
# Urban population (% of total population)      Middle East & North Africa
# Urban population (% of total population)                      South Asia
# Urban population (% of total population)              Sub-Saharan Africa
# Urban population (% of total population)                   United States
#
#                                                1970       2020
# Indicator Name
# Urban population (% of total population)  50.780276  62.551291
# Urban population (% of total population)  24.952469  60.694853
# Urban population (% of total population)  65.672896  76.117928
# Urban population (% of total population)  57.266616  81.068041
# Urban population (% of total population)  42.653945  65.968229
# Urban population (% of total population)  18.637719  34.883009
# Urban population (% of total population)  18.125077  41.252152
# Urban population (% of total population)  73.602000  82.664000

# %%
#check the datatypes
reduced_df5.dtypes
# Out:
# Country Name     object
# 1970            float64
# 2020            float64
# dtype: object

# %%
#convert the 1970 column and 2020 column to integers rather than floats
cols = ['1970', '2020']
reduced_df5[cols] = reduced_df5[cols].applymap(np.int64)
reduced_df5
# Out:
#                                                             Country Name  \
# Indicator Name
# Urban population (% of total population)  Central Europe and the Baltics
# Urban population (% of total population)             East Asia & Pacific
# Urban population (% of total population)                  European Union
# Urban population (% of total population)       Latin America & Caribbean
# Urban population (% of total population)      Middle East & North Africa
# Urban population (% of total population)                      South Asia
# Urban population (% of total population)              Sub-Saharan Africa
# Urban population (% of total population)                   United States
#
#                                           1970  2020
# Indicator Name
# Urban population (% of total population)    50    62
# Urban population (% of total population)    24    60
# Urban population (% of total population)    65    76
# Urban population (% of total population)    57    81
# Urban population (% of total population)    42    65
# Urban population (% of total population)    18    34
# Urban population (% of total population)    18    41
# Urban population (% of total population)    73    82

# %%
#Move the Indicator Name index back into a column
reduced_df6 = reduced_df5.reset_index(level='Indicator Name')
reduced_df6
# Out:
#                              Indicator Name                    Country Name  \
# 0  Urban population (% of total population)  Central Europe and the Baltics
# 1  Urban population (% of total population)             East Asia & Pacific
# 2  Urban population (% of total population)                  European Union
# 3  Urban population (% of total population)       Latin America & Caribbean
# 4  Urban population (% of total population)      Middle East & North Africa
# 5  Urban population (% of total population)                      South Asia
# 6  Urban population (% of total population)              Sub-Saharan Africa
# 7  Urban population (% of total population)                   United States
#
#    1970  2020
# 0    50    62
# 1    24    60
# 2    65    76
# 3    57    81
# 4    42    65
# 5    18    34
# 6    18    41
# 7    73    82

# %%
# Reorganizing the columns where Country Name comes before Indicator Name
organized_df = reduced_df6[["Country Name","Indicator Name","1970","2020"]]
organized_df.head()
# Out:
#                      Country Name                            Indicator Name  \
# 0  Central Europe and the Baltics  Urban population (% of total population)
# 1             East Asia & Pacific  Urban population (% of total population)
# 2                  European Union  Urban population (% of total population)
# 3       Latin America & Caribbean  Urban population (% of total population)
# 4      Middle East & North Africa  Urban population (% of total population)
#
#    1970  2020
# 0    50    62
# 1    24    60
# 2    65    76
# 3    57    81
# 4    42    65

# %%
#Create New df
organized_df2=organized_df.copy()

# %%
# Create our difference column
organized_df2["Difference"] = organized_df2["2020"]-organized_df["1970"]
organized_df2
# Out:
#                      Country Name                            Indicator Name  \
# 0  Central Europe and the Baltics  Urban population (% of total population)
# 1             East Asia & Pacific  Urban population (% of total population)
# 2                  European Union  Urban population (% of total population)
# 3       Latin America & Caribbean  Urban population (% of total population)
# 4      Middle East & North Africa  Urban population (% of total population)
# 5                      South Asia  Urban population (% of total population)
# 6              Sub-Saharan Africa  Urban population (% of total population)
# 7                   United States  Urban population (% of total population)
#
#    1970  2020  Difference
# 0    50    62          12
# 1    24    60          36
# 2    65    76          11
# 3    57    81          24
# 4    42    65          23
# 5    18    34          16
# 6    18    41          23
# 7    73    82           9

# %%
#Sort the Difference column from high to low
high_to_low = organized_df2.sort_values("Difference", ascending=False)
high_to_low
# Out:
#                      Country Name                            Indicator Name  \
# 1             East Asia & Pacific  Urban population (% of total population)
# 3       Latin America & Caribbean  Urban population (% of total population)
# 4      Middle East & North Africa  Urban population (% of total population)
# 6              Sub-Saharan Africa  Urban population (% of total population)
# 5                      South Asia  Urban population (% of total population)
# 0  Central Europe and the Baltics  Urban population (% of total population)
# 2                  European Union  Urban population (% of total population)
# 7                   United States  Urban population (% of total population)
#
#    1970  2020  Difference
# 1    24    60          36
# 3    57    81          24
# 4    42    65          23
# 6    18    41          23
# 5    18    34          16
# 0    50    62          12
# 2    65    76          11
# 7    73    82           9

# %%
# Set x axis and tick locations
x_axis = np.arange(len(high_to_low))
tick_locations = [value for value in x_axis]

# %%
# Create a list indicating how to write x labels and set figure size
plt.figure(figsize=(10,6))
plt.bar(x_axis, high_to_low["Difference"], color=['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'orange', 'purple'], alpha=0.6, align="center")
plt.xticks(tick_locations, high_to_low["Country Name"], rotation=50, ha='right')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ([<matplotlib.axis.XTick at 0x265a439e488>,
#   <matplotlib.axis.XTick at 0x265892c7088>,
#   <matplotlib.axis.XTick at 0x265a4373648>,
#   <matplotlib.axis.XTick at 0x265a43e7348>,
#   <matplotlib.axis.XTick at 0x265a43e7788>,
#   <matplotlib.axis.XTick at 0x265a43e7d08>,
#   <matplotlib.axis.XTick at 0x265a43ec508>,
#   <matplotlib.axis.XTick at 0x265a43ecb88>],
#  <a list of 8 Text xticklabel objects>)

# %%
# Set a Title and labels and save our figure
plt.tight_layout()
plt.title("Urban Population as % of Total Population", fontsize=18)
plt.ylabel("% Difference 1970 to 2020", fontsize=14)
plt.tight_layout()
plt.savefig("Urban_pop.png")

# %%
# To create our next graph now using Rural population (% of total population), go back to df where we grabbed our Indicator Name
reduced_df_rural = reduced_df4.loc[["Rural population (% of total population)"]]
reduced_df_rural
# Out:
#                                                             Country Name  \
# Indicator Name
# Rural population (% of total population)  Central Europe and the Baltics
# Rural population (% of total population)             East Asia & Pacific
# Rural population (% of total population)                  European Union
# Rural population (% of total population)       Latin America & Caribbean
# Rural population (% of total population)      Middle East & North Africa
# Rural population (% of total population)                      South Asia
# Rural population (% of total population)              Sub-Saharan Africa
# Rural population (% of total population)                   United States
#
#                                                1970       2020
# Indicator Name
# Rural population (% of total population)  49.219724  37.448709
# Rural population (% of total population)  75.047531  39.305147
# Rural population (% of total population)  34.327104  23.882072
# Rural population (% of total population)  42.733384  18.931959
# Rural population (% of total population)  57.346055  34.031771
# Rural population (% of total population)  81.362281  65.116991
# Rural population (% of total population)  81.874923  58.747848
# Rural population (% of total population)  26.398000  17.336000

# %%
#convert the 1970 column and 2020 column to integers rather than floats
cols = ['1970', '2020']
reduced_df_rural[cols] = reduced_df_rural[cols].applymap(np.int64)
reduced_df_rural
# Out:
#                                                             Country Name  \
# Indicator Name
# Rural population (% of total population)  Central Europe and the Baltics
# Rural population (% of total population)             East Asia & Pacific
# Rural population (% of total population)                  European Union
# Rural population (% of total population)       Latin America & Caribbean
# Rural population (% of total population)      Middle East & North Africa
# Rural population (% of total population)                      South Asia
# Rural population (% of total population)              Sub-Saharan Africa
# Rural population (% of total population)                   United States
#
#                                           1970  2020
# Indicator Name
# Rural population (% of total population)    49    37
# Rural population (% of total population)    75    39
# Rural population (% of total population)    34    23
# Rural population (% of total population)    42    18
# Rural population (% of total population)    57    34
# Rural population (% of total population)    81    65
# Rural population (% of total population)    81    58
# Rural population (% of total population)    26    17

# %%
#Move the Indicator Name index back into a column
reduced_df_rural2 = reduced_df_rural.reset_index(level='Indicator Name')
reduced_df_rural2
# Out:
#                              Indicator Name                    Country Name  \
# 0  Rural population (% of total population)  Central Europe and the Baltics
# 1  Rural population (% of total population)             East Asia & Pacific
# 2  Rural population (% of total population)                  European Union
# 3  Rural population (% of total population)       Latin America & Caribbean
# 4  Rural population (% of total population)      Middle East & North Africa
# 5  Rural population (% of total population)                      South Asia
# 6  Rural population (% of total population)              Sub-Saharan Africa
# 7  Rural population (% of total population)                   United States
#
#    1970  2020
# 0    49    37
# 1    75    39
# 2    34    23
# 3    42    18
# 4    57    34
# 5    81    65
# 6    81    58
# 7    26    17

# %%
# Reorganizing the columns where Country Name comes before Indicator Name
organized_rural = reduced_df_rural2[["Country Name","Indicator Name","1970","2020"]]
organized_rural.head()
# Out:
#                      Country Name                            Indicator Name  \
# 0  Central Europe and the Baltics  Rural population (% of total population)
# 1             East Asia & Pacific  Rural population (% of total population)
# 2                  European Union  Rural population (% of total population)
# 3       Latin America & Caribbean  Rural population (% of total population)
# 4      Middle East & North Africa  Rural population (% of total population)
#
#    1970  2020
# 0    49    37
# 1    75    39
# 2    34    23
# 3    42    18
# 4    57    34

# %%
#Create New df
organized_rural2=organized_rural.copy()

# %%
# Create our difference column
organized_rural2["Difference"] = organized_rural2["2020"]-organized_rural2["1970"]
organized_rural2
# Out:
#                      Country Name                            Indicator Name  \
# 0  Central Europe and the Baltics  Rural population (% of total population)
# 1             East Asia & Pacific  Rural population (% of total population)
# 2                  European Union  Rural population (% of total population)
# 3       Latin America & Caribbean  Rural population (% of total population)
# 4      Middle East & North Africa  Rural population (% of total population)
# 5                      South Asia  Rural population (% of total population)
# 6              Sub-Saharan Africa  Rural population (% of total population)
# 7                   United States  Rural population (% of total population)
#
#    1970  2020  Difference
# 0    49    37         -12
# 1    75    39         -36
# 2    34    23         -11
# 3    42    18         -24
# 4    57    34         -23
# 5    81    65         -16
# 6    81    58         -23
# 7    26    17          -9

# %%
#Sort the Difference column from high to low
high_to_low_rural = organized_rural2.sort_values("Difference", ascending=False)
high_to_low_rural
# Out:
#                      Country Name                            Indicator Name  \
# 7                   United States  Rural population (% of total population)
# 2                  European Union  Rural population (% of total population)
# 0  Central Europe and the Baltics  Rural population (% of total population)
# 5                      South Asia  Rural population (% of total population)
# 4      Middle East & North Africa  Rural population (% of total population)
# 6              Sub-Saharan Africa  Rural population (% of total population)
# 3       Latin America & Caribbean  Rural population (% of total population)
# 1             East Asia & Pacific  Rural population (% of total population)
#
#    1970  2020  Difference
# 7    26    17          -9
# 2    34    23         -11
# 0    49    37         -12
# 5    81    65         -16
# 4    57    34         -23
# 6    81    58         -23
# 3    42    18         -24
# 1    75    39         -36

# %%
# Set x axis and tick locations
x_axis = np.arange(len(high_to_low_rural))
tick_locations = [value for value in x_axis]

# %%
# Create a list indicating how to write x labels and set figure size
plt.figure(figsize=(10,6))
plt.bar(x_axis, high_to_low_rural["Difference"], color=['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'orange', 'purple'], alpha=0.6, align="center")
plt.xticks(tick_locations, high_to_low_rural["Country Name"], rotation=50, ha='right')
# Out:
# <div id='f0613846-4c01-4ec6-ae41-042ae6b711a5'></div>
# ([<matplotlib.axis.XTick at 0x265a80c4688>,
#   <matplotlib.axis.XTick at 0x265a80b2f08>,
#   <matplotlib.axis.XTick at 0x265a80a0248>,
#   <matplotlib.axis.XTick at 0x265a8102e08>,
#   <matplotlib.axis.XTick at 0x265a8104608>,
#   <matplotlib.axis.XTick at 0x265a8104dc8>,
#   <matplotlib.axis.XTick at 0x265a810a9c8>,
#   <matplotlib.axis.XTick at 0x265a810a408>],
#  <a list of 8 Text xticklabel objects>)

# %%
# Set a Title and labels
plt.tight_layout()
plt.title('Rural Population as % of Total Population', fontdict={'fontweight':'bold', 'fontsize': 18})
plt.ylabel("% Difference 1970 to 2020", fontsize=14)
plt.tight_layout()
plt.savefig("Rural_pop.png")
